# %% [markdown]
# # Example 101 (Interactive Mode)

# %% [markdown]
# The following basic example is written in interactive mode to show how trusspy works. *For mid-sized models it may be more convenient to use a Spreadsheet (Excel) - input file*. All model parameters except allowed incremental quantities are assumed with default values to enable a clean tutorial for the model creation process. We will consider a model with two nodes and one truss. Although this configuration does not include any geometric nonlinear effects it is the most basic example to start with. The left end of the truss (Node 1) is fixed whereas the right end displacement is free in direction x (Node 2). An external force acts on the right end of the truss in direction x. To sum up, this model contains two nodes, one element and one degree of freedom (DOF).

# %% [markdown]
# First we import trusspy with it’s own namespace and create a Model object M.

# %%
import trusspy as tp

# init model
M = tp.Model()
# Out:
#          _____                  ______
#         |_   _|                 | ___ \
#           | |_ __ _   _ ___ ___ | |_/ /   _
#           | | '__| | | / __/ __||  __/ | | |
#           | | |  | |_| \__ \__ \| |  | |_| |
#           \_/_|   \__,_|___/___/\_|   \__, |
#                                        __/ |
#                                       |___/
#
#         TrussPy - Object Oriented Truss Solver for Python
#                   Version 2018.08 (Build 20180829)
#
#         Author: Dutzler A.
#                 Graz University of Technology, 2018
#
#         TrussPy  Copyright (C) 2018  Andreas Dutzler
#         This program comes with ABSOLUTELY NO WARRANTY;
#         for details type `trusspy.show_w()'.
#         This is free software, and you are welcome to redistribute it
#         under certain conditions; type `trusspy.show_c()' for details.
#
#
# # Initialize Model
# * loading Managers
#
#     - finished.

# %% [markdown]
# Now we create Nodes with coordinate triples and Elements with a list of node connectivities and both material and geometric properties. Both Nodes and Elements are identified with their label.

# %%
# create nodes
#
#    tp.Node( label,  coord  )
# ----------------------------
N1 = tp.Node(1, (0, 0, 0))
N2 = tp.Node(2, (1, 0, 0))

# create element
young = 1
area = 1
E1 = tp.Element(1, [1, 2], material_properties=[young], geometric_properties=[area])

# %% [markdown]
# **Mechanical boundary conditions** must be supplied for all nodes which contain locked DOF’s: `0 = inactive (locked)` and `1 = active (free)`. The same applies to external forces - no **External Force** object has to be added to the **Model** if all components of a node are zero.

# %%
# create displacement (U) boundary conditions
B1 = tp.BoundaryU(1, (0, 0, 0))
B2 = tp.BoundaryU(2, (1, 0, 0))

# create external forces
# F1 = tp.ExternalForce( 1, (0,0,0) ) # not necessary
F2 = tp.ExternalForce(2, (1, 0, 0))

# %% [markdown]
# We have to specify some important **Settings Parameters** concerning the trusspy path-tracing algorithm:

# %%
M.Settings.dlpf = 0.02  # maximum allowed incremental load-proportionality-factor
M.Settings.du = 0.02  # maximum allowed incremental displacement component
M.Settings.incs = 50  # maximum number of increments

# %% [markdown]
# All generated items have to be added to the model `M`. Of course this is cumbersome for bigger models. Alternativly, one may wrap for example the Node object creation inside the `node_add` function of the Model object: `M.Nodes.add_node(tp.Node(label, coord))`. Either way we are able to build the model and run the job afterwards. The nodal ordering of Nodes, Boundaries and Forces inside the corresponding add function doesn’t matter. TrussPy will sort all nodal quantities by their node labels in the build method.

# %%
# add items to the model
M.Nodes.add_nodes([N1, N2])
M.Elements.add_element(E1)
M.Boundaries.add_bounds_U([B1, B2])
M.ExtForces.add_forces([F2])

# build model and run job
M.build()
M.run()
# Out:
# # Model Summary
#     Analysis Dimension      "ndim": 3
#     Number of Nodes       "nnodes": 2
#     Number of Elements    "nelems": 1
#
#     System DOF              "ndof": 6
#     active DOF             "ndof1": 1
#     locked DOF             "ndof2": 5
#
#     active DOF          "nproDOF1": [3]
#     fixed  DOF          "nproDOF0": [0 1 2 4 5]
# \pagebreak
#
# # Run Simulation
#
# ## Summary of Analysis Parameters
# |Description                          |Parameter|Value|
# |:------------------------------------|:--------|:--|
# |Maximum increments                   |   `incs`| 50 |
# |Maximum increment recycles           |   `cycl`| 4 |
# |Maximum Newton-Rhapson iterations    |   `nfev`| 8 |
# |Maximum incremental displacement     |     `du`| 0.02 |
# |Maximum incremental LPF              |   `dlpf`| 0.02 |
# |Initial control component            |     `j0`| LPF|
# |Locked control component             |`j_fixed`| False |
# |Maximum incremental overshoot        |  `dxtol`| 1.000001 |
# |Tolerance for x                      |   `xtol`| 8 |
# |Tolerance for f                      |   `ftol`| 8 |
#
#
# ## Step 1
# * i(1) is index with 1st-biggest component in abs(Dx/Dx,max).
# * i(2) is index with 2nd-biggest component in abs(Dx/Dx,max).
# * i(3) is index with 3rd-biggest component in abs(Dx/Dx,max).
# * i(4) is index with 4th-biggest component in abs(Dx/Dx,max).
# * Value(i) is value of i-th component in abs(Dx/Dx,max).
# $$\text{Value}_i = \left|\frac{D_x}{D_{x,max}}\right|_i$$
#
# ### Increment 1
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.735e-17|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.735e-17|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.735e-17|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.02
#
# ### Increment 2
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |3.469e-17|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |3.469e-17|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |3.469e-17|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.04
#
# ### Increment 3
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.665e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |5.551e-17|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |5.551e-17|   1|  1.0000|   2|  1.0000|   0|     nan|
#
# * final LPF:       0.06
#
# ### Increment 4
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   1   |1.388e-17|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.527e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.527e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.08
#
# ### Increment 5
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |8.327e-17|   1|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |0.000e+00|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   1   |0.000e+00|   1|  1.0000|   2|  1.0000|   0|     nan|
#
# * final LPF:        0.1
#
# ### Increment 6
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   1   |1.388e-17|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.388e-17|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.388e-17|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.12
#
# ### Increment 7
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |2.776e-17|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |2.776e-17|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |2.776e-17|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.14
#
# ### Increment 8
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |5.551e-17|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.665e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.665e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.16
#
# ### Increment 9
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |8.327e-17|   1|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |0.000e+00|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   1   |0.000e+00|   1|  1.0000|   2|  1.0000|   0|     nan|
#
# * final LPF:       0.18
#
# ### Increment 10
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   1   |2.776e-17|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |2.776e-17|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |2.776e-17|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:        0.2
#
# ### Increment 11
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |5.551e-17|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |5.551e-17|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |5.551e-17|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.22
#
# ### Increment 12
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.388e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |8.327e-17|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |8.327e-17|   1|  1.0000|   2|  1.0000|   0|     nan|
#
# * final LPF:       0.24
#
# ### Increment 13
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   1   |0.000e+00|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.26
#
# ### Increment 14
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.28
#
# ### Increment 15
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:        0.3
#
# ### Increment 16
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.32
#
# ### Increment 17
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.34
#
# ### Increment 18
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.36
#
# ### Increment 19
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.38
#
# ### Increment 20
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:        0.4
#
# ### Increment 21
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.42
#
# ### Increment 22
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.44
#
# ### Increment 23
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.46
#
# ### Increment 24
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.48
# ### Increment 25
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:        0.5
#
# ### Increment 26
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.52
#
# ### Increment 27
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.54
#
# ### Increment 28
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.56
#
# ### Increment 29
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.58
#
# ### Increment 30
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:        0.6
#
# ### Increment 31
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.62
#
# ### Increment 32
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.64
#
# ### Increment 33
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.66
#
# ### Increment 34
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.68
#
# ### Increment 35
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:        0.7
#
# ### Increment 36
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.72
#
# ### Increment 37
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.74
#
# ### Increment 38
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.76
#
# ### Increment 39
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.78
#
# ### Increment 40
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:        0.8
#
# ### Increment 41
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.82
#
# ### Increment 42
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.84
#
# ### Increment 43
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.86
#
# ### Increment 44
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.88
#
# ### Increment 45
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:        0.9
#
# ### Increment 46
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.92
#
# ### Increment 47
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.94
#
# ### Increment 48
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.96
#
# ### Increment 49
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |1.110e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |1.110e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |1.110e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:       0.98
#
# ### Increment 50
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |  1  |   0  |   2   |2.220e-16|   2|       1|    |        |    |        |
#
# |Cycle|NR-It.|Control| Norm(g) |i(1)|Value   |i(2)|Value   |i(3)|Value   |
# |:---:|:----:|:-----:|:-------:|:--:|:------:|:--:|:------:|:--:|:------:|
# |     |   1  |       |2.220e-16|    |        |    |        |    |        |
# |total| sum  | used  |  final  |    | final  |    | final  |    | final  |
# |  1  |   2  |   2   |2.220e-16|   2|  1.0000|   1|  1.0000|   0|     nan|
#
# * final LPF:          1
# \pagebreak
#
#
# ### Create result object from analysis results for step   1
#
#     write result   1/ 50 (LPF:       0.02)
#     write result   2/ 50 (LPF:       0.04)
#     write result   3/ 50 (LPF:       0.06)
#     write result   4/ 50 (LPF:       0.08)
#     write result   5/ 50 (LPF:        0.1)
#     write result   6/ 50 (LPF:       0.12)
#     write result   7/ 50 (LPF:       0.14)
#     write result   8/ 50 (LPF:       0.16)
#     write result   9/ 50 (LPF:       0.18)
#     write result  10/ 50 (LPF:        0.2)
#     write result  11/ 50 (LPF:       0.22)
#     write result  12/ 50 (LPF:       0.24)
#     write result  13/ 50 (LPF:       0.26)
#     write result  14/ 50 (LPF:       0.28)
#     write result  15/ 50 (LPF:        0.3)
#     write result  16/ 50 (LPF:       0.32)
#     write result  17/ 50 (LPF:       0.34)
#     write result  18/ 50 (LPF:       0.36)
#     write result  19/ 50 (LPF:       0.38)
#     write result  20/ 50 (LPF:        0.4)
#     write result  21/ 50 (LPF:       0.42)
#     write result  22/ 50 (LPF:       0.44)
#     write result  23/ 50 (LPF:       0.46)
#     write result  24/ 50 (LPF:       0.48)
#     write result  25/ 50 (LPF:        0.5)
#     write result  26/ 50 (LPF:       0.52)
#     write result  27/ 50 (LPF:       0.54)
#     write result  28/ 50 (LPF:       0.56)
#     write result  29/ 50 (LPF:       0.58)
#     write result  30/ 50 (LPF:        0.6)
#     write result  31/ 50 (LPF:       0.62)
#     write result  32/ 50 (LPF:       0.64)
#     write result  33/ 50 (LPF:       0.66)
#     write result  34/ 50 (LPF:       0.68)
#     write result  35/ 50 (LPF:        0.7)
#     write result  36/ 50 (LPF:       0.72)
#     write result  37/ 50 (LPF:       0.74)
#     write result  38/ 50 (LPF:       0.76)
#     write result  39/ 50 (LPF:       0.78)
#     write result  40/ 50 (LPF:        0.8)
#     write result  41/ 50 (LPF:       0.82)
#     write result  42/ 50 (LPF:       0.84)
#     write result  43/ 50 (LPF:       0.86)
#     write result  44/ 50 (LPF:       0.88)
#     write result  45/ 50 (LPF:        0.9)
#     write result  46/ 50 (LPF:       0.92)
#     write result  47/ 50 (LPF:       0.94)
#     write result  48/ 50 (LPF:       0.96)
#     write result  49/ 50 (LPF:       0.98)
#     write result  50/ 50 (LPF:          1)
#
# End of Step 1
# \pagebreak
#
#
# ## Job duration
# Time measurement for execution times of "Model.build()" and "Model.run()".
#
#     total  cpu time "build":      0.002 seconds
#     total wall time "build":      0.002 seconds
#
#     total  cpu time "run":        0.393 seconds
#     total wall time "run":        0.393 seconds

# %% [markdown]
# When the job has finished we may post-process the deformed model and plot the force-displacement curve at Node 2.

# %%
# show results
M.plot_model(
    config=["deformed"],
    view="xz",
    contour="force",
    lim_scale=(-0.5, 3.5, -2, 2),
    force_scale=1.0,
    inc=-1,
);

# %% [markdown]
# The deformed model with the current **External Force** vector acting on **Node** 2.

# %%
M.plot_history(nodes=[2, 2], X="Displacement X", Y="Force X");

# %% [markdown]
# The load-displacement curve for all increments at **Node** 2.

# %% [markdown]
# It could also be helpful to show the animated deformation process within a simple GIF file (options should be self-explaining). The resulting movie is saved to `figures/gif/movie.gif` whereas all deformed states are saved as `figures/png/fig_###.png`

# %%
# show results
M.plot_movie(
    config=["deformed"],
    view="xz",
    contour="force",
    lim_scale=(-0.5, 3.5, -2, 2),
    force_scale=1.0,
    cbar_limits=[-1, 1],
)

# %% [markdown]
# *Important Note*: A **LOT** of assumptions are made to run this model without specifying barely any parameter. Most important ones are incremental displacement values, incremental LPF value and the amount of increments to be solved. These critical parameters are responsible if the model solution will converge or not!
